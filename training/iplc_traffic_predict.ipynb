# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"..\datasets\iplctraffic.csv")
dataset
# Out:
#      m_id   max_in_g
# 0       1  487.20244
# 1       2  526.76689
# 2       3  541.89909
# 3       4  552.03859
# 4       5  565.13116
# 5       6  553.78122
# 6       7  549.44168
# 7       8  532.52101
# 8       9  542.54831
# 9      10  557.15090
# 10     11  570.73565
# 11     12  566.58589
# 12     13  563.29318
# 13     14  586.80645
# 14     15  593.23868
# 15     16  567.70624
# 16     17  566.39699
# 17     18  561.13881
# 18     19  565.91278
# 19     20  556.49596
# 20     21  567.97593
# 21     22  575.87026
# 22     23  590.62021
# 23     24  578.23840
# 24     25  592.44570
# 25     26  582.90254
# 26     27  549.78095
# 27     28  556.45189
# 28     29  567.42645
# 29     30  568.72879
# ..    ...        ...
# 212   213  690.85802
# 213   214  689.05841
# 214   215  702.20643
# 215   216  724.84892
# 216   217  674.84179
# 217   218  690.39272
# 218   219  682.44158
# 219   220  704.08249
# 220   221  710.97830
# 221   222  736.92520
# 222   223  649.23725
# 223   224  705.20290
# 224   225  718.97760
# 225   226  716.34944
# 226   227  724.65244
# 227   228  718.48532
# 228   229  744.38220
# 229   230  665.31203
# 230   231  709.05247
# 231   232  756.13920
# 232   233  719.81811
# 233   234  735.25466
# 234   235  715.47292
# 235   236  704.23078
# 236   237  726.64615
# 237   238  713.42059
# 238   239  724.02065
# 239   240  728.53622
# 240   241  758.32763
# 241   242  738.61342
#
# [242 rows x 2 columns]

# %%
X = dataset.iloc[ : ,   : 1 ].values
Y = dataset.iloc[ : , 1 ].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split( X, Y, test_size = 1/4, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor = regressor.fit(X_train, Y_train)
Y_pred = regressor.predict(X_test)

# %%
plt.scatter(X_train , Y_train, color = 'red')
plt.plot(X_train , regressor.predict(X_train), color ='blue')

# %%
xp= []
for i in range(1,366):
    xp.append([i])

# %%
plt.scatter(X , Y, color = 'red')
plt.plot(xp , regressor.predict(xp), color ='blue')
